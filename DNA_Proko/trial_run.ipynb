# %%
# !pip install git+https://github.com/evo-design/proto-language.git
# Out:
# DEPRECATION: Loading egg at /Users/marcamil/anaconda3/lib/python3.11/site-packages/tensorflow_addons-0.23.0-py3.11-macosx-11.1-arm64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/marcamil/anaconda3/lib/python3.11/site-packages/typeguard-2.13.3-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/marcamil/anaconda3/lib/python3.11/site-packages/protein_bert-1.0.1-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/marcamil/anaconda3/lib/python3.11/site-packages/pyfaidx-0.8.1.1-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting git+https://github.com/evo-design/proto-language.git
#   Cloning https://github.com/evo-design/proto-language.git to /private/var/folders/7x/7scxxbdj6fz3w64qtgzb5pxm0000gn/T/pip-req-build-wv37ffn2
#   Running command git clone --filter=blob:none --quiet https://github.com/evo-design/proto-language.git /private/var/folders/7x/7scxxbdj6fz3w64qtgzb5pxm0000gn/T/pip-req-build-wv37ffn2
#   Resolved https://github.com/evo-design/proto-language.git to commit 4558d1e58ddf9cdaaebc76de1a5a60dc7cdfc42a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting proto_tools@ git+https://github.com/evo-design/proto-tools.git@main (from proto-language==0.1.0)
#   Cloning https://github.com/evo-design/proto-tools.git (to revision main) to /private/var/folders/7x/7scxxbdj6fz3w64qtgzb5pxm0000gn/T/pip-install-fteip3nb/proto-tools_8d26a6e782e847c186015c4ed73ce1b9
#   Running command git clone --filter=blob:none --quiet https://github.com/evo-design/proto-tools.git /private/var/folders/7x/7scxxbdj6fz3w64qtgzb5pxm0000gn/T/pip-install-fteip3nb/proto-tools_8d26a6e782e847c186015c4ed73ce1b9
#   Resolved https://github.com/evo-design/proto-tools.git to commit cd417b48e4c1e4a6869297ea5ff3e034ae0625c4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pydantic>=2.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (2.9.2)
# Requirement already satisfied: numpy>=1.20 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (2.2.6)
# Requirement already satisfied: pandas>=1.5 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (2.2.2)
# Requirement already satisfied: scipy>=1.10 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.3.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (1.7.0)
# Requirement already satisfied: biopython>=1.81 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (1.83)
# Requirement already satisfied: biotite<1.2.0,>=0.38.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (1.0.1)
# Requirement already satisfied: rdkit!=2026.3.3 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (2024.3.6)
# Requirement already satisfied: jupyter in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (1.0.0)
# Requirement already satisfied: ipykernel in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (6.25.0)
# Requirement already satisfied: ipywidgets in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (8.0.4)
# Requirement already satisfied: ipymol in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (0.5)
# Requirement already satisfied: py3Dmol in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (2.5.5)
# Requirement already satisfied: matplotlib in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (3.7.2)
# Requirement already satisfied: tqdm in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (4.67.1)
# Requirement already satisfied: openpyxl in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (3.1.3)
# Requirement already satisfied: docstring-parser in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-language==0.1.0) (0.18.0)
# Requirement already satisfied: biotraj<2.0,>=1.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (1.2.2)
# Requirement already satisfied: msgpack>=0.5.6 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (1.0.3)
# Requirement already satisfied: networkx>=2.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (3.1)
# Requirement already satisfied: requests>=2.12 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from pandas>=1.5->proto-language==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from pandas>=1.5->proto-language==0.1.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from pandas>=1.5->proto-language==0.1.0) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from pydantic>=2.0->proto-language==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from pydantic>=2.0->proto-language==0.1.0) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from pydantic>=2.0->proto-language==0.1.0) (4.12.2)
# Requirement already satisfied: Pillow in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from rdkit!=2026.3.3->proto-language==0.1.0) (9.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.3.0->proto-language==0.1.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.3.0->proto-language==0.1.0) (3.1.0)
# Requirement already satisfied: appnope in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (1.5.6)
# Requirement already satisfied: packaging in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (23.1)
# Requirement already satisfied: psutil in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipykernel->proto-language==0.1.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipywidgets->proto-language==0.1.0) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipywidgets->proto-language==0.1.0) (3.0.5)
# Requirement already satisfied: notebook in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jupyter->proto-language==0.1.0) (6.5.4)
# Requirement already satisfied: qtconsole in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jupyter->proto-language==0.1.0) (5.4.2)
# Requirement already satisfied: jupyter-console in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jupyter->proto-language==0.1.0) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jupyter->proto-language==0.1.0) (6.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from matplotlib->proto-language==0.1.0) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from matplotlib->proto-language==0.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from matplotlib->proto-language==0.1.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from matplotlib->proto-language==0.1.0) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from matplotlib->proto-language==0.1.0) (3.0.9)
# Requirement already satisfied: et-xmlfile in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from openpyxl->proto-language==0.1.0) (1.1.0)
# Requirement already satisfied: pyarrow in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (17.0.0)
# Requirement already satisfied: umap-learn>=0.5.3 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.5.6)
# Requirement already satisfied: numba>=0.60.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.66.0)
# Requirement already satisfied: gemmi in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.7.5)
# Requirement already satisfied: promotercalculator in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (1.2.4)
# Requirement already satisfied: pyyaml in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (6.0)
# Requirement already satisfied: filelock in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (3.9.0)
# Requirement already satisfied: proto-client>=0.1.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.1.0)
# Requirement already satisfied: backcall in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.2.0)
# Requirement already satisfied: decorator in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (2.15.1)
# Requirement already satisfied: stack-data in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->proto-language==0.1.0) (4.8.0)
# Requirement already satisfied: entrypoints in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel->proto-language==0.1.0) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->proto-language==0.1.0) (3.10.0)
# Requirement already satisfied: llvmlite<0.49,>=0.48.0dev0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from numba>=0.60.0->proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.48.0)
# Requirement already satisfied: httpx>=0.27 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from proto-client>=0.1.0->proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.27.2)
# Requirement already satisfied: six>=1.5 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5->proto-language==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from requests>=2.12->biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from requests>=2.12->biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from requests>=2.12->biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from requests>=2.12->biotite<1.2.0,>=0.38.0->proto-language==0.1.0) (2023.7.22)
# Requirement already satisfied: pynndescent>=0.5 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from umap-learn>=0.5.3->proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.5.12)
# Requirement already satisfied: lxml in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (4.12.2)
# Requirement already satisfied: bleach in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->proto-language==0.1.0) (1.2.1)
# Requirement already satisfied: argon2-cffi in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->proto-language==0.1.0) (21.3.0)
# Requirement already satisfied: ipython-genutils in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->proto-language==0.1.0) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->proto-language==0.1.0) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->proto-language==0.1.0) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->proto-language==0.1.0) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->proto-language==0.1.0) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from qtconsole->jupyter->proto-language==0.1.0) (2.2.0)
# Requirement already satisfied: anyio in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->proto-client>=0.1.0->proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->proto-client>=0.1.0->proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (1.0.5)
# Requirement already satisfied: sniffio in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->proto-client>=0.1.0->proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27->proto-client>=0.1.0->proto_tools@ git+https://github.com/evo-design/proto-tools.git@main->proto-language==0.1.0) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.8.3)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->proto-language==0.1.0) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->proto-language==0.1.0) (0.2.2)
# Requirement already satisfied: fastjsonschema in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->proto-language==0.1.0) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->proto-language==0.1.0) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter->proto-language==0.1.0) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->proto-language==0.1.0) (2.4)
# Requirement already satisfied: webencodings in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert->jupyter->proto-language==0.1.0) (0.5.1)
# Requirement already satisfied: executing in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.8.3)
# Requirement already satisfied: asttokens in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->proto-language==0.1.0) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->proto-language==0.1.0) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->proto-language==0.1.0) (24.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->proto-language==0.1.0) (0.18.0)
# Requirement already satisfied: websocket-client in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->proto-language==0.1.0) (1.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->proto-language==0.1.0) (1.15.1)
# Requirement already satisfied: pycparser in /Users/marcamil/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->proto-language==0.1.0) (2.21)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from proto_language.core import Segment, Construct
from proto_language.generator import RandomNucleotideGenerator, RandomNucleotideGeneratorConfig

# Create a segment and construct
segment = Segment(length=50, sequence_type="dna")
construct = Construct(segments=[segment])

# Set up a generator
generator = RandomNucleotideGenerator(RandomNucleotideGeneratorConfig())
generator.assign(segment)

print(f"Segment: {segment.sequence_length}bp {segment.sequence_type}")
print("Installation successful!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from proto_language.core import Segment, Construct
#       2 from proto_language.generator import RandomNucleotideGenerator, RandomNucleotideGeneratorConfig
#       4 # Create a segment and construct
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_language/__init__.py:3
#       1 """Public API surface for proto-language."""
# ----> 3 from proto_language.constraint import (
#       4     AbLangPerplexityConfig,
#       5     AF3ChainPairProtDNAIPTMConfig,
#       6     AF3OffTargetIPTMSpecificityConfig,
#       7     AlphaFold2BinderStructureConfig,
#       8     AlphaGenomeSpliceJunctionConfig,
#       9     BorzoiChromatinAccessibilityMorseConfig,
#      10     BorzoiTrackActivityConfig,
#      11     BorzoiTrackInterval,
#      12     ConsensusSpecificityConfig,
#      13     ConstraintRegistry,
#      14     ConstraintSpec,
#      15     DBPDesignMetricsConfig,
#      16     DeepPBSMotifSpecificityConfig,
#      17     DNABaseContactQualityConfig,
#      18     DNAMotifContactCountConfig,
#      19     DNAPhosphateContactConfig,
#      20     EnformerChromatinAccessibilityMorseConfig,
#      21     ESM2PerplexityConfig,
#      22     MalinoisActivityCellType,
#      23     MalinoisActivityConfig,
#      24     MalinoisActivityDirection,
#      25     MiRNASpecificityConfig,
#      26     MpnnPerplexityConfig,
#      27     NAMPNNMotifSpecificityConfig,
#      28     OperatorSiteConfig,
#      29     ProteinDNAIpsaeConfig,
#      30     PuffinPromoterActivityConfig,
#      31     PyRosettaInterfaceConfig,
#      32     StructureBasedConstraintConfig,
#      33     TargetScanSiteConfig,
#      34     ablang_perplexity_constraint,
#      35     ablang_perplexity_gradient_backward,
#      36     af3_chain_pair_prot_dna_iptm_constraint,
#      37     af3_offtarget_iptm_specificity_constraint,
#      38     alphagenome_interval_track_constraint,
#      39     alphagenome_splice_junction_constraint,
#      40     alphagenome_splice_site_usage,
#      41     balanced_aa_constraint,
#      42     boltz_binding_strength_constraint,
#      43     borzoi_chromatin_accessibility_morse_constraint,
#      44     borzoi_track_activity_constraint,
#      45     consensus_operator_specificity_constraint,
#      46     constraint,
#      47     crispr_array_constraint,
#      48     crispr_tracr_rna_constraint,
#      49     dbp_design_metrics_constraint,
#      50     deeppbs_motif_specificity_constraint,
#      51     dinucleotide_composition_constraint,
#      52     dna_base_contact_quality_constraint,
#      53     dna_motif_contact_count_constraint,
#      54     dna_phosphate_contact_constraint,
#      55     enformer_chromatin_accessibility_morse_constraint,
#      56     esm2_perplexity_constraint,
#      57     esm2_perplexity_gradient_backward,
#      58     gap_gini_constraint,
#      59     gc_content_constraint,
#      60     gyration_radius_constraint,
#      61     kmer_frequency_constraint,
#      62     longest_orf_length_constraint,
#      63     malinois_activity_constraint,
#      64     max_homopolymer_constraint,
#      65     mirna_specificity_constraint,
#      66     mmseqs_similarity_constraint,
#      67     mpnn_perplexity_constraint,
#      68     mpnn_perplexity_gradient_backward,
#      69     na_mpnn_motif_specificity_constraint,
#      70     operator_site_constraint,
#      71     overall_protein_quality_constraint,
#      72     promoter_strength_constraint,
#      73     protein_complexity_constraint,
#      74     protein_diversity_constraint,
#      75     protein_dna_ipsae_constraint,
#      76     protein_domain_constraint,
#      77     protein_globularity_constraint,
#      78     protein_length_constraint,
#      79     protein_max_identity_constraint,
#      80     protein_nearest_neighbor_gap_gini_constraint,
#      81     protein_profile_hmm_constraint,
#      82     protein_repetitiveness_constraint,
#      83     protein_symmetry_ring_constraint,
#      84     puffin_promoter_activity_constraint,
#      85     pyrosetta_interface_constraint,
#      86     rna_basepair_similarity_constraint,
#      87     rna_feature_similarity_constraint,
#      88     rna_motif_similarity_constraint,
#      89     rna_property_similarity_constraint,
#      90     seq_motif_constraint,
#      91     sequence_length_constraint,
#      92     sigma70_promoter_constraint,
#      93     specific_kmer_constraint,
#      94     splice_transformer_intron_boundary,
#      95     splice_transformer_specificity,
#      96     structure_beta_strand_constraint,
#      97     structure_composite_constraint,
#      98     structure_contact_constraint,
#      99     structure_distogram_cce_constraint,
#     100     structure_ensemble_rmsd_constraint,
#     101     structure_helix_constraint,
#     102     structure_interface_contact_constraint,
#     103     structure_ipae_constraint,
#     104     structure_iplddt_constraint,
#     105     structure_iptm_constraint,
#     106     structure_pae_constraint,
#     107     structure_plddt_constraint,
#     108     structure_ptm_constraint,
#     109     structure_radius_gyration_constraint,
#     110     structure_rmsd_constraint,
#     111     structure_termini_distance_constraint,
#     112     structure_tmscore_constraint,
#     113     targetscan_site_constraint,
#     114 )
#     115 from proto_language.core import (
#     116     BaseConfig,
#     117     BaseRegistry,
#    (...)
#     129     SequenceType,
#     130 )
#     131 from proto_language.generator import (
#     132     ESM2Generator,
#     133     ESM2GeneratorConfig,
#    (...)
#     164     generator,
#     165 )
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_language/constraint/__init__.py:4
#       1 """Constraint registry and all registered constraint functions."""
#       3 # Base infrastructure
# ----> 4 from proto_language.constraint.constraint_registry import (
#       5     ConstraintRegistry,
#       6     ConstraintSpec,
#       7     InputSlot,
#       8     constraint,
#       9 )
#      11 # Protein quality constraints
#      12 from proto_language.constraint.protein_quality import (
#      13     balanced_aa_constraint,
#      14     overall_protein_quality_constraint,
#    (...)
#      22     protein_repetitiveness_constraint,
#      23 )
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_language/constraint/constraint_registry.py:14
#      11 from pydantic import BaseModel, Field, field_serializer
#      12 from pydantic.json_schema import SkipJsonSchema
# ---> 14 from proto_language.core import Constraint, Segment
#      15 from proto_language.core.constraint import GradientConstraintOutput, InputSlot
#      16 from proto_language.utils.base import BaseRegistry, BaseSpec
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_language/core/__init__.py:8
#       3 # ruff: noqa: I001
#       4 # Import order matters: .sequence and .segment must come before .construct
#       5 # because construct.py does `from . import Segment, Sequence`.
#       6 from proto_language.utils.base import BaseConfig, BaseRegistry, BaseSpec
# ----> 8 from proto_language.core.sequence import (
#       9     DNA_NUCLEOTIDES,
#      10     PROTEIN_AMINO_ACIDS,
#      11     RNA_NUCLEOTIDES,
#      12     Sequence,
#      13     SequenceType,
#      14     create_concatenated_sequence,
#      15     detect_sequence_type,
#      16     return_invalid_dna_chars,
#      17     return_invalid_nucleotide_chars,
#      18     return_invalid_protein_chars,
#      19     return_invalid_rna_chars,
#      20     validate_smiles,
#      21 )
#      22 from proto_language.core.segment import Segment
#      23 from proto_language.core.constraint import (
#      24     Constraint,
#      25     ConstraintFunction,
#    (...)
#      28     InputSlot,
#      29 )
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_language/core/sequence.py:30
#      27 from typing import Any, Literal
#      29 import numpy as np
# ---> 30 from proto_tools.entities.structures import Structure
#      32 logger = logging.getLogger(__name__)
#      34 # Valid characters for different sequence types
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_tools/__init__.py:15
#      12 # Put source-tree standalone_helpers/ on sys.path so parent-side imports of standalone modules can resolve `from standalone_helpers import X` (subprocess inserts the per-tool copy ahead of this).
#      13 _sys.path.append(str(_Path(__file__).parent / "utils" / "standalone_helpers_source"))
# ---> 15 from proto_tools.utils.logging_config import (  # noqa: F401
#      16     get_logger,
#      17     install_logger_class,
#      18     install_spinner_handler,
#      19     setup_logging,
#      20 )
#      22 # Make every getLogger return a ProtoLogger so update_status=True works as a kwarg.
#      23 install_logger_class()
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_tools/utils/__init__.py:7
#       1 """Shared utilities for proto_tools.
#       2
#       3 Config, helpers, sequence validation, I/O, caching, env management, device, logging.
#       4 """
#       6 from proto_tools.utils.auth import require_hf_token
# ----> 7 from proto_tools.utils.base_config import BaseConfig, ConfigField
#       8 from proto_tools.utils.chemistry import validate_smiles
#       9 from proto_tools.utils.device import (
#      10     determine_visible_devices,
#      11     display_gpu_memory_usage,
#    (...)
#      14     number_of_available_gpus,
#      15 )
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_tools/utils/base_config.py:13
#      10 from pydantic import BaseModel, ConfigDict
#      11 from pydantic import Field as PydanticField
# ---> 13 from proto_tools.utils.tool_io import (
#      14     BaseToolInput,
#      15     _extra_dict,
#      16     _reject_removed_ui_kwargs,
#      17     _require_title_and_description,
#      18 )
#      20 DEFAULT_TIMEOUT = 3600  # seconds (generous default; heavy GPU tools need headroom under load)
#      21 RANDOM_SEED_UPPER_BOUND = 2**31
#
# File ~/anaconda3/lib/python3.11/site-packages/proto_tools/utils/tool_io.py:17
#      14 from pathlib import Path
#      15 from typing import Any, ClassVar, Literal, TypedDict
# ---> 17 from pydantic import BaseModel, ConfigDict, Field, ModelWrapValidatorHandler, model_validator
#      19 from proto_tools.utils.compressed_array import is_compressed_array
#      20 from proto_tools.utils.export_names import sanitize_field
#
# ImportError: cannot import name 'ModelWrapValidatorHandler' from 'pydantic' (/Users/marcamil/anaconda3/lib/python3.11/site-packages/pydantic/__init__.py)
